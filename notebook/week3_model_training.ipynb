# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from xgboost import XGBRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error
)

import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/processed_data.csv')

# %%
df.head()
# Out:
#         id        week  center_id  meal_id  checkout_price  base_price  \
# 0  1499955  2020-01-02         55     1062          182.36      183.36
# 1  1351400  2020-01-02         24     1062          184.36      182.36
# 2  1057835  2020-01-02         11     1062          184.36      182.36
# 3  1231510  2020-01-02         83     1062          170.78      170.78
# 4  1402151  2020-01-02         32     1062          175.60      174.60
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  ...  \
# 0                      0                  0         391        647  ...
# 1                      0                  0         514        614  ...
# 2                      0                  0         798        679  ...
# 3                      0                  0         284        659  ...
# 4                      0                  0         256        526  ...
#
#    category_Salad  category_Sandwich  category_Seafood  category_Soup  \
# 0           False              False             False          False
# 1           False              False             False          False
# 2           False              False             False          False
# 3           False              False             False          False
# 4           False              False             False          False
#
#    category_Starters  cuisine_Indian  cuisine_Italian  cuisine_Thai  \
# 0              False           False             True         False
# 1              False           False             True         False
# 2              False           False             True         False
# 3              False           False             True         False
# 4              False           False             True         False
#
#    center_type_TYPE_B  center_type_TYPE_C
# 0               False                True
# 1                True               False
# 2               False               False
# 3               False               False
# 4               False               False
#
# [5 rows x 38 columns]

# %%
y = df['num_orders']

X = df.drop(['num_orders'], axis=1)

# %%
X = X.drop(['week'], axis=1)

# %%
split_index = int(len(df) * 0.8)

X_train = X.iloc[:split_index]

X_test = X.iloc[split_index:]

y_train = y.iloc[:split_index]

y_test = y.iloc[split_index:]

# %%
lr_model = LinearRegression()

lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_pred = lr_model.predict(X_test)

# %%
lr_mae = mean_absolute_error(y_test, lr_pred)

lr_rmse = np.sqrt(
    mean_squared_error(y_test, lr_pred)
)

print("Linear Regression MAE:", lr_mae)

print("Linear Regression RMSE:", lr_rmse)
# Out:
# Linear Regression MAE: 131.85486726483038
# Linear Regression RMSE: 209.484487765148

# %%
rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
rf_pred = rf_model.predict(X_test)

# %%
rf_mae = mean_absolute_error(y_test, rf_pred)

rf_rmse = np.sqrt(
    mean_squared_error(y_test, rf_pred)
)

print("Random Forest MAE:", rf_mae)

print("Random Forest RMSE:", rf_rmse)
# Out:
# Random Forest MAE: 110.757238090023
# Random Forest RMSE: 179.85847797894132

# %%
xgb_model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=8,
    random_state=42
)

xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_pred = xgb_model.predict(X_test)

# %%
xgb_mae = mean_absolute_error(y_test, xgb_pred)

xgb_rmse = np.sqrt(
    mean_squared_error(y_test, xgb_pred)
)

print("XGBoost MAE:", xgb_mae)

print("XGBoost RMSE:", xgb_rmse)
# Out:
# XGBoost MAE: 104.06986236572266
# XGBoost RMSE: 180.11568548088752

# %%
results = pd.DataFrame({
    'Model': [
        'Linear Regression',
        'Random Forest',
        'XGBoost'
    ],

    'MAE': [
        lr_mae,
        rf_mae,
        xgb_mae
    ],

    'RMSE': [
        lr_rmse,
        rf_rmse,
        xgb_rmse
    ]
})

results
# Out:
#                Model         MAE        RMSE
# 0  Linear Regression  131.854867  209.484488
# 1      Random Forest  110.757238  179.858478
# 2            XGBoost  104.069862  180.115685

# %%
plt.figure(figsize=(15,6))

plt.plot(
    y_test.values[:200],
    label='Actual Orders'
)

plt.plot(
    xgb_pred[:200],
    label='Predicted Orders'
)

plt.legend()

plt.title('Actual vs Predicted Food Demand')

plt.xlabel('Samples')

plt.ylabel('Orders')

plt.show()

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': xgb_model.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

# %%
importance.head(10)
# Out:
#                   Feature  Importance
# 17         rolling_mean_7    0.318790
# 9                 op_area    0.087286
# 6       homepage_featured    0.064701
# 25     category_Rice Bowl    0.045192
# 8             region_code    0.041315
# 32        cuisine_Italian    0.036324
# 5   emailer_for_promotion    0.033038
# 20        category_Extras    0.028762
# 1               center_id    0.027589
# 7               city_code    0.026501

# %%
top_features = importance.head(10)

plt.figure(figsize=(10,5))

plt.barh(
    top_features['Feature'],
    top_features['Importance']
)

plt.title('Top 10 Important Features')

plt.gca().invert_yaxis()

plt.show()

# %%
import joblib

joblib.dump(
    xgb_model,
    '../models/xgboost_model.pkl'
)
# Out:
# ['../models/xgboost_model.pkl']

# %%
results.to_csv(
    '../data/model_results.csv',
    index=False
)
